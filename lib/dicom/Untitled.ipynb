# %%
import os
from os.path import dirname, join

import numpy as np
import nibabel as nib
import matplotlib
import matplotlib.pyplot as plt

from __future__ import unicode_literals  # Only for python2.7 and save_as unicode filename
import pydicom
from pydicom.dataset import Dataset, FileDataset, FileMetaDataset
from pydicom.sequence import Sequence

# %%
t2Dir=r'E:\Users\tr17\Documents\Projects\PC_Fetal_CMR\Data\dicom_fcmr_4d\t2'
os.chdir(t2Dir)

ds = pydicom.dcmread('t2_phant.dcm')

# %%
print(len(ds))
ds
# Out:
# 409
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 200
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Enhanced MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 1.3.46.670589.11.41376.5.20.1.1.9036.2018092720331978031
# (0002, 0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 1844
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'T2', 'NONE']
# (0008, 0012) Instance Creation Date              DA: '20180927'
# ...

# %%
with open('t2dcm.txt', 'w') as f:
    print(ds, file=f)
